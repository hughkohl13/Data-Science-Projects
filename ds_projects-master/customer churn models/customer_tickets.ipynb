# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

# %%
pd.__version__
# Out:
# '0.25.1'

# %%
custs = pd.read_csv('group_performance_group_performance_6_months-15-Apr-20-12-02.csv')
custs.columns = ['Group', 'tickets_assigned', 'percentage', 'tickets_resolved',
       'tickets_reopened', 'tickets_reassigned', 'first_response_SLA_perc',
       'resolution_SLA_perc', 'FCR_perc', 'private_notes', 'responses',
       'average_1st_response_time', 'average_response_time',
       'average_resolution_time']

# %%
custs.tail()
# Out:
#                    Group  tickets_assigned  percentage  tickets_resolved  \
# 26  Aurora Organic Dairy             248.0         NaN             255.0
# 27        Red Wing Shoes            1067.0         NaN            1108.0
# 28   Next Day Boat Parts               NaN         NaN               2.0
# 29                   NaN               NaN         NaN               NaN
# 30                 total            1892.0         NaN               NaN
#
#     tickets_reopened  tickets_reassigned  first_response_SLA_perc  \
# 26              24.0                 NaN                     82.0
# 27              73.0                 NaN                     59.0
# 28               NaN                 NaN                      NaN
# 29               NaN                 NaN                      NaN
# 30               NaN                 NaN                      NaN
#
#     resolution_SLA_perc  FCR_perc  private_notes  responses  \
# 26                 73.0      67.0          112.0      193.0
# ...

# %%
custs.iloc[26:28, :]
# Out:
#                    Group  tickets_assigned  percentage  tickets_resolved  \
# 26  Aurora Organic Dairy             248.0         NaN             255.0
# 27        Red Wing Shoes            1067.0         NaN            1108.0
#
#     tickets_reopened  tickets_reassigned  first_response_SLA_perc  \
# 26              24.0                 NaN                     82.0
# 27              73.0                 NaN                     59.0
#
#     resolution_SLA_perc  FCR_perc  private_notes  responses  \
# 26                 73.0      67.0          112.0      193.0
# 27                 75.0      74.0         1507.0      565.0
#
#    average_1st_response_time average_response_time average_resolution_time
# 26                   5:22:37               6:05:42                31:01:16
# 27                  12:52:12              12:23:36                30:49:06

# %%
custs.drop([28,29,30], axis=0, inplace=True).tail(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-bed31fae8bd4> in <module>
# ----> 1 custs.drop([28,29,30], axis=0, inplace=True).tail(3)
#
# AttributeError: 'NoneType' object has no attribute 'tail'

# %%
custs.describe()
# Out:
#        tickets_assigned  percentage  tickets_resolved  tickets_reopened  \
# count         28.000000    2.000000         28.000000         17.000000
# mean          67.571429    0.000733         70.535714          9.823529
# std          204.539126    0.000289        212.311351         17.500840
# min            1.000000    0.000529          1.000000          1.000000
# 25%            3.750000    0.000631          4.000000          1.000000
# 50%            7.000000    0.000733          8.500000          4.000000
# 75%           25.250000    0.000835         25.250000          7.000000
# max         1067.000000    0.000937       1108.000000         73.000000
#
#        tickets_reassigned  first_response_SLA_perc  resolution_SLA_perc  \
# count            6.000000                24.000000            28.000000
# mean             1.833333                67.666667            51.964286
# std              0.752773                28.120342            30.850274
# ...

# %%
custs.groupby('Group').sum().sort_values('tickets_assigned', ascending=False)
# Out:
#                               tickets_assigned  percentage  tickets_resolved  \
# Group
# Red Wing Shoes                          1067.0    0.000000            1108.0
# Aurora Organic Dairy                     248.0    0.000000             255.0
# Grosfillex                               180.0    0.000000             183.0
# Berkshire Corporation                    136.0    0.000000             151.0
# Vida Brands                               45.0    0.000000              52.0
# Rose Packing                              42.0    0.000000              42.0
# STORD                                     32.0    0.000000              32.0
# Bargreen Ellingson                        23.0    0.000000              23.0
# Weinbrenner                               21.0    0.000000              21.0
# Kuli Kuli                                 17.0    0.000000              18.0
# m3_users@aodmilk.com                       9.0    0.000000               9.0
# ...

# %%
custs['percentage'] = (custs['tickets_assigned']) /(custs['tickets_assigned'].sum())

# %%
custs
# Out:
#                            Group  tickets_assigned  percentage  \
# 0                           UTSE               1.0    0.000529
# 1                         Wencor               1.0    0.000529
# 2                       Chubbies               2.0    0.001057
# 3                       Frontier               3.0    0.001586
# 4                     GeekSeller               3.0    0.001586
# 5                       Shipwell               3.0    0.001586
# 6                   Snack Nation               3.0    0.001586
# 7            Fresh Water Systems               4.0    0.002114
# 8              John Soules Foods               4.0    0.002114
# 9   Specialty Foods Distribution               4.0    0.002114
# 10              Trinity Partners               4.0    0.002114
# 11                   Drink Tanks               5.0    0.002643
# 12                        Emerge               5.0    0.002643
# 13                  Shelf Engine               7.0    0.003700
# ...

# %%
custs_wo_redwing = custs.drop([27] , axis=0)
custs_wo_redwing
# Out:
#                            Group  tickets_assigned  percentage  \
# 0                           UTSE               1.0    0.000529
# 1                         Wencor               1.0    0.000529
# 2                       Chubbies               2.0    0.001057
# 3                       Frontier               3.0    0.001586
# 4                     GeekSeller               3.0    0.001586
# 5                       Shipwell               3.0    0.001586
# 6                   Snack Nation               3.0    0.001586
# 7            Fresh Water Systems               4.0    0.002114
# 8              John Soules Foods               4.0    0.002114
# 9   Specialty Foods Distribution               4.0    0.002114
# 10              Trinity Partners               4.0    0.002114
# 11                   Drink Tanks               5.0    0.002643
# 12                        Emerge               5.0    0.002643
# 13                  Shelf Engine               7.0    0.003700
# ...

# %%
custs_wo_redwing_aod = custs.drop([26,27] , axis=0)
custs_wo_redwing_aod
custs_wo_redwing_aod['percentage'] = (custs_wo_redwing_aod['tickets_assigned']) /(custs_wo_redwing_aod['tickets_assigned'].sum())

# %%
custs_wo_redwing_aod.plot.bar('Group', 'percentage')
