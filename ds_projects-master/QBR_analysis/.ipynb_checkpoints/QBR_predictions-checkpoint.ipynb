# %%
import matplotlib.pyplot as plt
import math
import pandas_datareader as web
import pandas as pd
import numpy as np
import seaborn as sns
import re

# %matplotlib inline

# %%
pwd
# Out:
# '/Users/hughkohl/Desktop/data-science-projects/Data-Science-Projects/ds_projects-master/QBR_analysis'

# %%
df_ent = pd.read_excel('../../../../SnS_QBR_data/Test_Public_List__Renewable_Entitlements__97373__02-07-2020.xlsx', header=9)

# %%
df_ent.head(14)
# Out:
#                             Tab name  \
# 0            Customer Site Reference
# 1                Agreement Reference
# 2               Entitlements by Site
# 3            Entitlements by Product
# 4                Sales Order History
# 5            Charge Document History
# 6           Charge Document Billings
# 7                    Product History
# 8    Charge Document Product History
# 9                  Evolution Details
# 10  Renewable Entitlements - Summary
# 11   Renewable Entitlements - Detail
# 12            Product(s) Not Evolved
# 13          CTL and ML Order History
#
#                                       Tab description  Unnamed: 2  Unnamed: 3
# 0   This tab lists the reference information for t...         NaN         NaN
# 1   This tab lists the reference information for t...         NaN         NaN
# 2   This tab contains the entitlements summarized ...         NaN         NaN
# 3   This tab contains the entitlements summarized ...         NaN         NaN
# 4   This tab contains the sales order history for ...         NaN         NaN
# 5   This tab contains the charge document sales or...         NaN         NaN
# 6   This tab contains the billings associated with...         NaN         NaN
# 7   This tab contains the sales order product hist...         NaN         NaN
# 8   This tab contains the charge document product ...         NaN         NaN
# 9   This tab contains the evolution history for th...         NaN         NaN
# 10  This tab contains the Renewable Entitlements S...         NaN         NaN
# 11  This tab contains the Renewable Entitlements D...         NaN         NaN
# 12  This tab in the Product History and Evolution ...         NaN         NaN
# 13  This tab contains the committed term license a...         NaN         NaN
