# %%
import matplotlib.pyplot as plt
import math
import pandas_datareader as web
import pandas as pd
import numpy as np
import seaborn as sns
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.preprocessing import MinMaxScaler
plt.style.use('fivethirtyeight')
import re

# %matplotlib inline

# %%
df = pd.read_excel('./data/Customer_attrition.xlsx', header=3)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#                Customer Name  Site Number    Industry  \
# 0  SONEPAR MANAGEMENT US INC      3002962  Enterprise
# 1  SONEPAR MANAGEMENT US INC      3002962  Enterprise
# 2  SONEPAR MANAGEMENT US INC      3002962  Enterprise
# 3  SONEPAR MANAGEMENT US INC      3002962  Enterprise
# 4  SONEPAR MANAGEMENT US INC      3002962  Enterprise
#
#   Sub ISU Account Designation        Program Type Site Anniversary Date  \
# 0         Wholesale- Durables  Passport Advantage                 04/01
# 1         Wholesale- Durables  Passport Advantage                 04/01
# 2         Wholesale- Durables  Passport Advantage                 04/01
# 3         Wholesale- Durables  Passport Advantage                 04/01
# 4         Wholesale- Durables  Passport Advantage                 04/01
#
#                 Market                SS Rep                 SS FLM  \
# 0  Distribution Market  Gutierrez, Markus P.  Muncrief, Jennifer M.
# ...

# %%
df_placeholder = []
for i in df.columns:
    i = i.replace(' ', '_')
    df_placeholder.append(i)
    
df_placeholder
# Out:
# ['Customer_Name',
#  'Site_Number',
#  'Industry',
#  'Sub_ISU_Account_Designation',
#  'Program_Type',
#  'Site_Anniversary_Date',
#  'Market',
#  'SS_Rep',
#  'SS_FLM',
#  'Software_Name',
#  'Brand',
#  'Reseller_Name',
#  'Payer_Name',
#  'USD_Extended_Price',
#  'Attrition_Type',
#  'Dropped_SS_since_Q1_2020',
#  'Current_S&S_Quantity',
#  'SS_End_Date',
#  'Latest_Renewal_or_License_Part_number',
#  'Reinstatement_Part_Number',
#  'PA_Renewal_Contact_First_Name',
#  'PA_Renewal_Contact_Last_Name',
#  'Contact_Phone_Number',
#  'Email']

# %%
df.columns = df_placeholder
df.columns
# Out:
# Index(['Customer_Name', 'Site_Number', 'Industry',
#        'Sub_ISU_Account_Designation', 'Program_Type', 'Site_Anniversary_Date',
#        'Market', 'SS_Rep', 'SS_FLM', 'Software_Name', 'Brand', 'Reseller_Name',
#        'Payer_Name', 'USD_Extended_Price', 'Attrition_Type',
#        'Dropped_SS_since_Q1_2020', 'Current_S&S_Quantity', 'SS_End_Date',
#        'Latest_Renewal_or_License_Part_number', 'Reinstatement_Part_Number',
#        'PA_Renewal_Contact_First_Name', 'PA_Renewal_Contact_Last_Name',
#        'Contact_Phone_Number', 'Email'],
#       dtype='object')

# %%
cust_df = df.groupby('Customer_Name').sum().sort_values('Dropped_SS_since_Q1_2020',ascending=False).reset_index()[['Customer_Name','Dropped_SS_since_Q1_2020','Current_S&S_Quantity']]

# %%
cust_df['ss_difference'] = cust_df['Dropped_SS_since_Q1_2020'] - cust_df['Current_S&S_Quantity']

# %%
cust_df.query('ss_difference < 0').sort_values('ss_difference').head(10)
# Out:
#                                          Customer_Name  \
# 31                             Prime Therapeutics, LLC
# 39                                Harland Clarke Corp.
# 191  University of Iowa Hospitals and Clinics Healt...
# 193                           The Sportsman Guide Inc.
# 40                               McCormick and Company
# 178                      Ontario Securities Commission
# 155                NATIONAL GUARDIAN LIFE INSURANCE CO
# 261  FOUR SEASONS, INC, A DIVISION OF ST ANDARD MOT...
# 117                     Office of Personnel Management
# 238                          ROBERT HALF INTERNATIONAL
#
#      Dropped_SS_since_Q1_2020  Current_S&S_Quantity  ss_difference
# 31                       3424                 18103         -14679
# 39                       2537                  8465          -5928
# 191                       120                  1370          -1250
# 193                       112                  1008           -896
# ...

# %%
df.groupby(['Software_Name', 'Customer_Name']).sum().sort_values('Dropped_SS_since_Q1_2020',ascending=False).reset_index()[['Software_Name','Customer_Name', 'Dropped_SS_since_Q1_2020','Current_S&S_Quantity']].head(30)
# Out:
#                                         Software_Name  \
# 0   FileNet Content Manager Eligible Participant R...
# 1    FileNet Content Manager Employee User Value Unit
# 2   WebSphere Application Server ND Processor Valu...
# 3   Spectrum Protect Extended Edition Processor Va...
# 4           InfoSphere DataStage Processor Value Unit
# 5   InfoSphere DataStage for Non-Production Proces...
# 6   Global Retention Policy and Schedule Managemen...
# 7                   WebSphere MQ Processor Value Unit
# 8   Security Identity and Access Assurance Authori...
# 9   WebSphere Application Server ND Processor Valu...
# 10  Spectrum Protect Extended Edition Processor Va...
# 11  Sterling Configure, Price, Quote Partner Sales...
# 12  FileNet Content Foundation Eligible Participan...
# 13  WebSphere Application Server ND Processor Valu...
# 14  Security Guardium Central Management and Aggre...
# 15  Spectrum Protect Extended Edition Processor Va...
# ...

# %%
pwd
# Out:
# '/Users/hughkohl/Desktop/data-science-projects/Data-Science-Projects/ds_projects-master/customer_analysis'

# %%
df = pd.read_excel('../../../../NA_Q4_2020_QBR_ 2020-06-24_Public_Market.xlsx', sheet_name='Raw_Data', header=3)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#               SS Rep Name           SS FLM                      SS BUE  \
# 0  PA Autorenewal Program  Volume Programs  FRANCIS, ELIZABETH (Betty)
# 1  PA Autorenewal Program  Volume Programs  FRANCIS, ELIZABETH (Betty)
# 2  PA Autorenewal Program  Volume Programs  FRANCIS, ELIZABETH (Betty)
# 3  PA Autorenewal Program  Volume Programs  FRANCIS, ELIZABETH (Betty)
# 4  PA Autorenewal Program  Volume Programs  FRANCIS, ELIZABETH (Betty)
#
#                    Customer Name  Site Number            Geo IMT/GMT (Market)  \
# 0  Georgia Department of Revenue      3000988  North America    Public Market
# 1  Georgia Department of Revenue      3000988  North America    Public Market
# 2  Health Alliance Medical Plans      3002334  North America    Public Market
# 3  Health Alliance Medical Plans      3002334  North America    Public Market
# 4  Health Alliance Medical Plans      3002334  North America    Public Market
#
#          Country     State  IBM Customer Number  ...  \
# ...

# %%
columns = ['SS Rep Name', 'SS FLM', 'SS BUE', 'Customer Name', 'Site Number',
       'Geo', 'IMT/GMT (Market)', 'Country', 'State', 'IBM Customer Number',
       'Agreement Number', 'Coverage Number', 'Enterprise Number',
       'SAP Sales Order Number', 'Site Anniversary Date', 'Market Assignment',
       'Contract Sub Option Code', 'Contract Sub Option Code Description',
       'Industry', 'Sub ISU Account Designation', 'ELA (Yes/No)',
       'Start Month', 'ACV Expired for Site', 'Software Name', 'Brand',
       'License Owned', 'Current S&S Quantity', 'SS End Date ',
       'Bridge to Cloud Flag', 'Cloud Pak Trade Up/Upgrade Eligible',
       'Cloud Pak Name', 'Red Hat Entitlement Owned by Customer?',
       'Red Hat Part Number', 'Suspicious Renewal?',
       'Suspicious Renewal Reason', 'Reachback / Reinstatement Available?',
       'Reachback / Reinstatement Quantity',
       'Eligible for Standalone Product Trade Up?', 'Product to Trade Up to',
       'Disc Letter', 'Unit Price',
       'Reinstatement Opportunity \n(Unit Price x Reinstatement Quantity)',
       'Renewal Part Number', 'Reinstatement Part Number',
       'License Part Number', '6 Week Solution Build *Recommended ($78,600)',
       'One Week Solution Architecture ($16,000)',
       'One Week Infrastructure Build ($13,100)',
       'One Day Consulting Fees ($2,950)', 'First Name', 'Last Name',
       'Contact Phone Number', 'Email']

# %%
column = []
for i in columns:
    i = re.sub(' ', '_', i)
    column.append(i)

# %%
df.columns = [re.sub('&','n',column) for column in df.columns]

# %%
df.columns = [re.sub(' ','_',column) for column in df.columns]

# %%
df_matt = df.query('SS_Rep_Name == "Degrace, Matthew (M.L.)"') 
df_mich = df.query('SS_Rep_Name == "McKissack, Michael R."') 
df_deni = df.query('SS_Rep_Name == "Kaltekis, Denise (D.)"') 
df_nanc = df.query('SS_Rep_Name == "Yodis, Nancy J."')

# %%
# Which software_name has the most reinstatement oppt.?
df.groupby(['Software_Name', 'ELA_(Yes/No)']).sum().reset_index()[['ELA_(Yes/No)','Software_Name','Current_S&S_Quantity', 'ACV_Expired_for_Site', 'Reachback_/_Reinstatement_Quantity','Reinstatement_Opportunity_\n(Unit_Price_x_Reinstatement_Quantity)']].sort_values('Reinstatement_Opportunity_\n(Unit_Price_x_Reinstatement_Quantity)',ascending=False).head(10)
# Out:
#      ELA_(Yes/No)                                      Software_Name  \
# 1079           No  FileNet Image Manager Active Edition Authorize...
# 3329           No  Spectrum Protect Extended Edition Processor Va...
# 3311           No  Spectrum Control Standard Edition Storage Capa...
# 3399           No  Spectrum Protect for Databases Processor Value...
# 3309           No  Spectrum Control Standard Edition Storage Capa...
# 3317           No  Spectrum Control Standard Edition Storage Capa...
# 319            No  Cognos Business Intelligence Analytics User Pr...
# 3404           No                  Spectrum Protect for HSM Terabyte
# 3788           No              Tivoli Monitoring Resource Value Unit
# 3377           No        Spectrum Protect Suite Terabyte (1251-2000)
#
#       Current_S&S_Quantity  ACV_Expired_for_Site  \
# 1079                     0              55269.96
# 3329                 26838            1952540.52
# 3311                     0                  0.00
# ...

# %%
df_tot = df.groupby(['Customer_Name','Software_Name']).sum().reset_index()[['Customer_Name','Software_Name','License_Owned','Current_SnS_Quantity', 'ACV_Expired_for_Site', 'Reachback_/_Reinstatement_Quantity','Reinstatement_Opportunity_\n(Unit_Price_x_Reinstatement_Quantity)']].sort_values('Current_SnS_Quantity', ascending=False)

# %%
df_tot.query('Current_SnS_Quantity > 0').groupby('Customer_Name').sum()
# Out:
#                                                     License_Owned  \
# Customer_Name
# Almost Family/Caretenders                                    1620
# Arthrex Inc.                                                 8844
# BLUE CROSS & BLUE SHIELD OF MS                              26386
# BOSTON SCIENTIFIC CORPORATION VS BOSTON SCIENTIFIC          18135
# Blue Cross Blue Shield of Massachusetts                    119813
# ...                                                           ...
# University of Connecticut                                   11114
# University of Dayton                                          375
# University of Delaware Network & Systems Services             801
# University of Tennessee                                      8221
# WEST VIRGINIA UNITED HEALTH SYSTEM                            264
#
#                                                     Current_SnS_Quantity  \
# Customer_Name
# ...
